# %%
# coding: utf-8
import requests
import os
import math
import urllib
import re
import datetime

API_KEY = "e6bf06e9e4384cbca996d0cb7178808f"

def make_dir(path):
    if not os.path.isdir(path):
        os.mkdir(path)

def search_term2file_name(search_term):
    return re.sub('\s+', '_', search_term)

def get_headers(api_key):
    return {"Ocp-Apim-Subscription-Key" : api_key}

def get_params(search_term, num_imgs_per_transaction, offset):
    return urllib.parse.urlencode({
        "q": search_term + ' musician',
        "license": "All",
        "imageType": "photo",
        "count":num_imgs_per_transaction,
        "offset": offset * num_imgs_per_transaction})

def get_search_results(search_url, headers, params):
    response = requests.get(search_url, headers=headers, params=params)
    response.raise_for_status()
    search_results = response.json()
    return search_results

def save_urls(results, filepath):    
    with open(filepath, mode='a') as f:
        
        for values in results:
            if values['encodingFormat'] == 'jpeg':
                print(values['contentUrl'], file=f)
            elif values['encodingFormat'] == 'png':
                print(values['contentUrl'], file=f)

def get_filename(path, fn, ext):
    return os.path.join(path, '%s.%s' % (fn, ext))

def gen_url_save_file(search_term, url_dir_path, total_count):
    ext = 'txt'
    fn = search_term2file_name(search_term)
    filename = get_filename(url_dir_path, fn, ext)
    dt = datetime.datetime.now().strftime("%Y%m%d%H%M%S")

    if os.path.isfile(filename):
        fn = '%s_%s' % (fn, dt)
        filename = get_filename(url_dir_path, fn, ext)
    with open(filename, mode='w') as f:
        print("date=%s, search_term=%s, totalEstimatedMatches=%d" % (dt, search_term, total_count), file=f)
    return filename


if __name__ == '__main__':
    save_dir_path = './bing'
    make_dir(save_dir_path)
    url_dir_path = os.path.join(save_dir_path, 'url')
    make_dir(url_dir_path)

    num_imgs_required = 500 # Number of images you want.
    num_imgs_per_transaction =100 # default 30, Max 150 images
    
    keywords=[]

    search_url = "https://api.cognitive.microsoft.com/bing/v7.0/images/search"
    headers = get_headers(API_KEY)
    
    f_names = open("musicians.txt","r")

    for line in f_names:
        names = line.strip()
        keywords.append(names)
            
    for j in range(len(keywords)):
        print(keywords[j])
        search_term = keywords[j]

        params = get_params(search_term, num_imgs_per_transaction, 0)

        first_search_results = get_search_results(search_url, headers, params)
        total_count = first_search_results["totalEstimatedMatches"]
        print("totalEstimatedMatches=%d" % total_count)

        filepath=gen_url_save_file(search_term, url_dir_path, total_count)

        print ("len=%d" % (len(first_search_results["value"])))
        save_urls(first_search_results["value"], filepath)

        if num_imgs_required > total_count :
            num_imgs_required = total_count

        offset_count = math.ceil(num_imgs_required / num_imgs_per_transaction)
        print('offset_count=%d' % offset_count)
        for offset in range(1, offset_count):
            params = get_params(search_term, num_imgs_per_transaction, offset)
            search_results = get_search_results(search_url, headers, params)

            print ("len=%d" % len(search_results["value"]))
            save_urls(search_results["value"], filepath)
# Out:
# Queen
# totalEstimatedMatches=885
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Billy Joel
# totalEstimatedMatches=805
# len=100
# offset_count=5
# len=99
# len=100
# len=100
# len=100
# Radiohead
# totalEstimatedMatches=768
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# David Bowie
# totalEstimatedMatches=738
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Aerosmith
# totalEstimatedMatches=844
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Jay-Z
# totalEstimatedMatches=955
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# The Beatles
# totalEstimatedMatches=874
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Franz Ferdinand
# totalEstimatedMatches=974
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Van Halen
# totalEstimatedMatches=687
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# John Legend
# totalEstimatedMatches=930
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Michael Jackson
# totalEstimatedMatches=749
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Taylor Swift
# totalEstimatedMatches=793
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Adele
# totalEstimatedMatches=832
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Katie Perry
# totalEstimatedMatches=944
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Justin Bieber
# totalEstimatedMatches=689
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# The White Stripes
# totalEstimatedMatches=791
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Stevie Wonder
# totalEstimatedMatches=905
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Kiss
# totalEstimatedMatches=778
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Metallica
# totalEstimatedMatches=913
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Snow Patrol
# totalEstimatedMatches=905
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Lady GaGa
# totalEstimatedMatches=901
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Gorillaz
# totalEstimatedMatches=864
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Louis Armstrong
# totalEstimatedMatches=630
# len=100
# offset_count=5
# len=100
# len=99
# len=100
# len=100
# Ben Folds
# totalEstimatedMatches=941
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Jack Johnson
# totalEstimatedMatches=588
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# N.E.R.D.
# totalEstimatedMatches=934
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Avril Lavigne
# totalEstimatedMatches=752
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Wolfgang Amadeus Mozart
# totalEstimatedMatches=552
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Frederic Chopin
# totalEstimatedMatches=663
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Claude Debussy
# totalEstimatedMatches=994
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Richard Wagner
# totalEstimatedMatches=591
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Maurice Ravel
# totalEstimatedMatches=984
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Sergei Rachmaninoff
# totalEstimatedMatches=922
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Green Day
# totalEstimatedMatches=919
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Mae West
# totalEstimatedMatches=912
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Fiona Apple
# totalEstimatedMatches=909
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Eagles
# totalEstimatedMatches=841
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Etta James
# totalEstimatedMatches=801
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Aqualung
# totalEstimatedMatches=756
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Oasis
# totalEstimatedMatches=845
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Britney Spears
# totalEstimatedMatches=834
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Rihanna
# totalEstimatedMatches=822
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Bob Dylan
# totalEstimatedMatches=752
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Arctic Monkeys
# totalEstimatedMatches=875
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Aretha Franklin
# totalEstimatedMatches=823
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Hall & Oats
# totalEstimatedMatches=692
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Lea Salonga
# totalEstimatedMatches=518
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Frank Sinatra
# totalEstimatedMatches=889
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Eminem
# totalEstimatedMatches=675
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Miles Davis
# totalEstimatedMatches=805
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Daft Punk
# totalEstimatedMatches=949
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Paolo Nutini
# totalEstimatedMatches=864
# len=100
# offset_count=5
# len=100
# len=100
# len=100
# len=100
# Donavon Frankenreiter
