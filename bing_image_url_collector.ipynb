# %%
# coding: utf-8
import requests
import os
import math
import urllib
import re
import datetime

API_KEY = "e6bf06e9e4384cbca996d0cb7178808f"

def make_dir(path):
    if not os.path.isdir(path):
        os.mkdir(path)

def search_term2file_name(search_term):
    return re.sub('\s+', '_', search_term)

def get_headers(api_key):
    return {"Ocp-Apim-Subscription-Key" : api_key}

def get_params(search_term, num_imgs_per_transaction, offset):
    return urllib.parse.urlencode({
        "q": search_term + ' musician',
        "license": "All",
        "imageType": "photo",
        "count":num_imgs_per_transaction,
        "offset": offset * num_imgs_per_transaction})

def get_search_results(search_url, headers, params):
    response = requests.get(search_url, headers=headers, params=params)
    response.raise_for_status()
    search_results = response.json()
    return search_results

def save_urls(results, filepath):    
    with open(filepath, mode='a') as f:
        
        for values in results:
            if values['encodingFormat'] == 'jpeg':
                print(values['contentUrl'], file=f)
            elif values['encodingFormat'] == 'png':
                print(values['contentUrl'], file=f)
#             else:
#                 print('skipped')
#                 continue

def get_filename(path, fn, ext):
    return os.path.join(path, '%s.%s' % (fn, ext))

def gen_url_save_file(search_term, url_dir_path, total_count):
    ext = 'txt'
    fn = search_term2file_name(search_term)
    filename = get_filename(url_dir_path, fn, ext)
    dt = datetime.datetime.now().strftime("%Y%m%d%H%M%S")

    if os.path.isfile(filename):
        fn = '%s_%s' % (fn, dt)
        filename = get_filename(url_dir_path, fn, ext)
    with open(filename, mode='w') as f:
        print("date=%s, search_term=%s, totalEstimatedMatches=%d" % (dt, search_term, total_count), file=f)
    return filename


if __name__ == '__main__':
    save_dir_path = './bing'
    make_dir(save_dir_path)
    url_dir_path = os.path.join(save_dir_path, 'url')
    make_dir(url_dir_path)

    num_imgs_required = 1000 # Number of images you want.
    num_imgs_per_transaction =150 # default 30, Max 150 images
    
    keywords=[]

    search_url = "https://api.cognitive.microsoft.com/bing/v7.0/images/search"
    headers = get_headers(API_KEY)
    
    f_names = open("musicians.txt","r")

    for line in f_names:
        names = line.strip()
        keywords.append(names)
            
    for j in range(len(keywords)):
        print(keywords[j])
        search_term = keywords[j]

        params = get_params(search_term, num_imgs_per_transaction, 0)

        first_search_results = get_search_results(search_url, headers, params)
        total_count = first_search_results["totalEstimatedMatches"]
        print("totalEstimatedMatches=%d" % total_count)

        filepath=gen_url_save_file(search_term, url_dir_path, total_count)

        print ("len=%d" % (len(first_search_results["value"])))
        save_urls(first_search_results["value"], filepath)

        if num_imgs_required > total_count :
            num_imgs_required = total_count

        offset_count = math.ceil(num_imgs_required / num_imgs_per_transaction)
        print('offset_count=%d' % offset_count)
        for offset in range(1, offset_count):
            params = get_params(search_term, num_imgs_per_transaction, offset)
            search_results = get_search_results(search_url, headers, params)

            print ("len=%d" % len(search_results["value"]))
            save_urls(search_results["value"], filepath)
# Out:
# Queen
# totalEstimatedMatches=885
# len=150
# offset_count=6
# len=150
# len=150
# len=150
# len=150
# len=143
# Billy Joel
# totalEstimatedMatches=806
# len=150
# offset_count=6
# len=150
# len=150
# len=150
# len=150
# len=55
# Radiohead
# totalEstimatedMatches=768
# len=150
# offset_count=6
# len=150
# len=150
# len=150
# len=150
# len=18
# David Bowie
# totalEstimatedMatches=739
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=138
# Aerosmith
# totalEstimatedMatches=838
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Jay-Z
# totalEstimatedMatches=968
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# The Beatles
# totalEstimatedMatches=874
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Franz Ferdinand
# totalEstimatedMatches=1000
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Van Halen
# totalEstimatedMatches=687
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=87
# John Legend
# totalEstimatedMatches=924
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Michael Jackson
# totalEstimatedMatches=749
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=149
# Taylor Swift
# totalEstimatedMatches=793
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Adele
# totalEstimatedMatches=828
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Katie Perry
# totalEstimatedMatches=944
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Justin Bieber
# totalEstimatedMatches=689
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=89
# The White Stripes
# totalEstimatedMatches=791
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Stevie Wonder
# totalEstimatedMatches=905
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Kiss
# totalEstimatedMatches=778
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Metallica
# totalEstimatedMatches=913
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Snow Patrol
# totalEstimatedMatches=903
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Lady GaGa
# totalEstimatedMatches=902
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Gorillaz
# totalEstimatedMatches=899
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Louis Armstrong
# totalEstimatedMatches=628
# len=150
# offset_count=5
# len=149
# len=150
# len=150
# len=28
# Ben Folds
# totalEstimatedMatches=941
# len=150
# offset_count=5
# len=150
# len=150
# len=150
# len=150
# Jack Johnson
# totalEstimatedMatches=588
# len=150
# offset_count=4
# len=150
# len=150
# len=138
# N.E.R.D.
# totalEstimatedMatches=934
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Avril Lavigne
# totalEstimatedMatches=752
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Wolfgang Amadeus Mozart
# totalEstimatedMatches=556
# len=150
# offset_count=4
# len=150
# len=150
# len=106
# Frederic Chopin
# totalEstimatedMatches=665
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Claude Debussy
# totalEstimatedMatches=989
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Richard Wagner
# totalEstimatedMatches=591
# len=150
# offset_count=4
# len=150
# len=150
# len=140
# Maurice Ravel
# totalEstimatedMatches=983
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Sergei Rachmaninoff
# totalEstimatedMatches=922
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Green Day
# totalEstimatedMatches=919
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Mae West
# totalEstimatedMatches=912
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Fiona Apple
# totalEstimatedMatches=909
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Eagles
# totalEstimatedMatches=841
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Etta James
# totalEstimatedMatches=801
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Aqualung
# totalEstimatedMatches=756
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Oasis
# totalEstimatedMatches=846
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Britney Spears
# totalEstimatedMatches=834
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Rihanna
# totalEstimatedMatches=822
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Bob Dylan
# totalEstimatedMatches=752
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Arctic Monkeys
# totalEstimatedMatches=875
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Aretha Franklin
# totalEstimatedMatches=823
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Hall & Oats
# totalEstimatedMatches=655
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Lea Salonga
# totalEstimatedMatches=518
# len=150
# offset_count=4
# len=150
# len=150
# len=68
# Frank Sinatra
# totalEstimatedMatches=889
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Eminem
# totalEstimatedMatches=689
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Miles Davis
# totalEstimatedMatches=805
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Daft Punk
# totalEstimatedMatches=912
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Paolo Nutini
# totalEstimatedMatches=865
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Donavon Frankenreiter
# totalEstimatedMatches=956
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Prince
# totalEstimatedMatches=669
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Original Broadway Cast "Rent
# totalEstimatedMatches=910
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# John Mayer
# totalEstimatedMatches=944
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Maroon 5
# totalEstimatedMatches=899
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Lenny Kravitz
# totalEstimatedMatches=868
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# The Rolling Stones
# totalEstimatedMatches=653
# len=150
# offset_count=4
# len=150
# len=150
# len=150
# Elton John
# totalEstimatedMatches=821
# len=150
# offset_count=4
# len=150
# len=150
# len=150
